# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Path to the five csv files
data_1 = "Resources/storm_data_2000 (1).csv"
data_2 = "Resources/storm_data_2011.csv"
data_3 = "Resources/storm_data_2016.csv"
data_4 = "Resources/storm_data_2020.csv"
data_5 = "Resources/storm_data_2021.csv"

# %%
# Read in the csv files
data_1 = pd.read_csv("Resources/storm_data_2000 (1).csv")
data_2 = pd.read_csv("Resources/storm_data_2011.csv")
data_3 = pd.read_csv("Resources/storm_data_2016.csv")
data_4 = pd.read_csv("Resources/storm_data_2020.csv")
data_5 = pd.read_csv("Resources/storm_data_2021.csv")

# %%
# Merge the data into one
merged_data = pd.concat([data_1, data_2, data_3, data_4, data_5], ignore_index=True)

# %%
merged_data
# Out:
#      EVENT_ID                                        CZ_NAME_STR  \
# 0       36754                 NORTHERN SAN JOAQUIN VALLEY (ZONE)
# 1       53471                  NORTHERN SACRAMENTO VALLEY (ZONE)
# 2       52840             SAN BERNARDINO COUNTY MOUNTAINS (ZONE)
# 3       52838                  RIVERSIDE COUNTY MOUNTAINS (ZONE)
# 4       52837                  SAN DIEGO COUNTY MOUNTAINS (ZONE)
# ..        ...                                                ...
# 984   1058453                       EASTERN MOJAVE DESERT (ZONE)
# 985   1058454                               MORONGO BASIN (ZONE)
# 986   1058455                                 CADIZ BASIN (ZONE)
# 987   1058456  SAN BERNARDINO COUNTY-UPPER COLORADO RIVER VAL...
# 988   1045584                     WESTERN SISKIYOU COUNTY (ZONE)
#
#     BEGIN_LOCATION  BEGIN_DATE  BEGIN_TIME      EVENT_TYPE MAGNITUDE  \
# 0                   05/08/2007           0  Excessive Heat
# ...

# %%
# List of columns to be deleted
columns_to_delete = ['BEGIN_LOCATION', 'MAGNITUDE', 'TOR_F_SCALE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE',
                     'TOR_LENGTH', 'TOR_WIDTH', 'BEGIN_RANGE', 'BEGIN_AZIMUTH', 'END_RANGE',
                     'END_AZIMUTH', 'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON']

# Create a new DataFrame with the specified columns deleted
heat_df = merged_data.drop(columns=columns_to_delete).copy()

# %%
heat_df
# Out:
#      EVENT_ID                                        CZ_NAME_STR  BEGIN_DATE  \
# 0       36754                 NORTHERN SAN JOAQUIN VALLEY (ZONE)  05/08/2007
# 1       53471                  NORTHERN SACRAMENTO VALLEY (ZONE)  07/04/2007
# 2       52840             SAN BERNARDINO COUNTY MOUNTAINS (ZONE)  07/04/2007
# 3       52838                  RIVERSIDE COUNTY MOUNTAINS (ZONE)  07/04/2007
# 4       52837                  SAN DIEGO COUNTY MOUNTAINS (ZONE)  07/04/2007
# ..        ...                                                ...         ...
# 984   1058453                       EASTERN MOJAVE DESERT (ZONE)  09/05/2022
# 985   1058454                               MORONGO BASIN (ZONE)  09/05/2022
# 986   1058455                                 CADIZ BASIN (ZONE)  09/05/2022
# 987   1058456  SAN BERNARDINO COUNTY-UPPER COLORADO RIVER VAL...  09/05/2022
# 988   1045584                     WESTERN SISKIYOU COUNTY (ZONE)  09/06/2022
#
# ...
